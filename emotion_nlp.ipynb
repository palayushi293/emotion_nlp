# %% [markdown]
# <a href="https://colab.research.google.com/github/palayushi293/emotion_nlp/blob/main/emotion_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-116b3cff-13ae-429a-b160-325fded780c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-116b3cff-13ae-429a-b160-325fded780c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from zipfile import ZipFile
dataset = '/content/emotion_nlp.zip'

with ZipFile(dataset,'r') as zip:
    zip.extractall()

# %%
# !ls
# Out:
# Emotion_classify_Data.csv  emotion_nlp.zip  sample_data

# %%
df=pd.read_csv('/content/Emotion_classify_Data.csv')

# %%
df.head()
# Out:
#                                              Comment Emotion
# 0  i seriously hate one subject to death but now ...    fear
# 1                 im so full of life i feel appalled   anger
# 2  i sit here to write i start to dig out my feel...    fear
# 3  ive been really angry with r and i feel like a...     joy
# 4  i feel suspicious if there is no one outside l...    fear

# %%
df.tail()
# Out:
#                                                 Comment Emotion
# 5932                 i begun to feel distressed for you    fear
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5934  i were to ever get married i d have everything...     joy
# 5935  i feel reluctant in applying there because i w...    fear
# 5936  i just wanted to apologize to you because i fe...   anger

# %%
df.describe()
# Out:
#                                                  Comment Emotion
# count                                               5937    5937
# unique                                              5934       3
# top     i feel like a tortured artist when i talk to her   anger
# freq                                                   2    2000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5937 entries, 0 to 5936
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Comment  5937 non-null   object
#  1   Emotion  5937 non-null   object
# dtypes: object(2)
# memory usage: 92.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Emotion']=label.fit_transform(df['Emotion'])

# %%
df
# Out:
#                                                 Comment  Emotion
# 0     i seriously hate one subject to death but now ...        1
# 1                    im so full of life i feel appalled        0
# 2     i sit here to write i start to dig out my feel...        1
# 3     ive been really angry with r and i feel like a...        2
# 4     i feel suspicious if there is no one outside l...        1
# ...                                                 ...      ...
# 5932                 i begun to feel distressed for you        1
# 5933  i left feeling annoyed and angry thinking that...        0
# 5934  i were to ever get married i d have everything...        2
# 5935  i feel reluctant in applying there because i w...        1
# 5936  i just wanted to apologize to you because i fe...        0
#
# [5937 rows x 2 columns]

# %%
import seaborn as sns

# %%
import re
def clean(text):
    text = re.sub('http\S+\s', ' ', text)
    text=re.sub('RT|cc',' ',text)
    #special character remove
    text = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', text)
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    text = re.sub('\s+',' ',text)
    text=re.sub('@\S+'' ','' ,text)
    text=re.sub('#\S+', ' ', text)

    return text

# %%
clean(df['Comment'][0])
# Out:
# 'i seriously hate one subject to death but now i feel reluctant to drop it'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer(stop_words='english')
x=tf.fit_transform(df['Comment'])

# %%
x.shape
# Out:
# (5937, 8671)

# %%
y=df['Emotion']

# %%
y.shape
# Out:
# (5937,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (4749, 8671)

# %%
x_test.shape
# Out:
# (1188, 8671)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred=knn.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.8173400673400674

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
ypred=rf.predict(x_test)
print(accuracy_score(y_test,ypred))
# Out:
# 0.9494949494949495

# %%
from sklearn import svm
sv=svm.SVC()
sv.fit(x_train,y_train)
ypred=sv.predict(x_test)
print(accuracy_score(y_test,ypred))
# Out:
# 0.9393939393939394

# %%
rain_predictions = knn.predict(x_train)
train_accuracy = accuracy_score(y_train, rain_predictions)
print( train_accuracy)
# Out:
# 0.8972415245314803
